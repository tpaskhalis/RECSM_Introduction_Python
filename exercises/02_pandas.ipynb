# %% [markdown]
# ## Exercise 2 - Pandas

# %% [markdown]
# Let's try subsetting and filtering on the [Kaggle 2020 Machine Learning and Data Science Survey](https://www.kaggle.com/c/kaggle-survey-2020/) dataset

# %%
import pandas as pd

# %%
## Read in the data
## Note that we won't create a composite column name this time
kaggle2020 = pd.read_csv('../data/kaggle_survey_2020_responses.csv')
# Out:
# /home/tpaskhalis/Decrypted/Git/RECSM_2021/venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
## Show top 5 rows
kaggle2020.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                1838                        35-39
# 2                              289287                        30-34
# 3                                 860                        35-39
# 4                                 507                        30-34
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
# 3                                  Argentina
# 4                   United States of America
#
# ...

# %%
## Show bottom 5 rows
kaggle2020.tail()
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 20032                                 126  18-21    Man
# 20033                                 566  55-59  Woman
# 20034                                 238  30-34    Man
# 20035                                 625  22-24    Man
# 20036                                1031  22-24    Man
#
#                                                       Q3  \
# 20032                                             Turkey
# 20033  United Kingdom of Great Britain and Northern I...
# 20034                                             Brazil
# 20035                                              India
# 20036                                           Pakistan
#
#                                                       Q4  \
# 20032  Some college/university study without earning ...
# 20033                                    Master’s degree
# 20034                                    Master’s degree
# ...

# %%
## Let's remove the first row that contains the question formulation
kaggle2020 = kaggle2020.drop(0)
kaggle2020
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 1                                    1838  35-39    Man
# 2                                  289287  30-34    Man
# 3                                     860  35-39    Man
# 4                                     507  30-34    Man
# 5                                      78  30-34    Man
# ...                                   ...    ...    ...
# 20032                                 126  18-21    Man
# 20033                                 566  55-59  Woman
# 20034                                 238  30-34    Man
# 20035                                 625  22-24    Man
# 20036                                1031  22-24    Man
#
#                                                       Q3  \
# 1                                               Colombia
# 2                               United States of America
# 3                                              Argentina
# 4                               United States of America
# ...

# %% [markdown]
# ### Task 1: Subset rows 100 to 110 from the dataset

# %%
## Add you code here

# %% [markdown]
# ### Task 2: Subset columns 1 to 5

# %%
## Add you code here

# %% [markdown]
# ### Task 3: Subset columns with all choices for Q7

# %%
## Add you code here

# %% [markdown]
# ### (Extra) Task 4: Filter dataset leaving only respondents who took more than 2 mins to respond. How many are dropped?
#
# Tip: As the correct parsing of column types was prevented by the first row with question formulation that we removed being string, you will need to convert the column type to numeric first. One way to achieve it is by using `pd.to_numeric()` method.

# %%
## Add you code here
