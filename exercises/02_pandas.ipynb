# %% [markdown]
# ## Exercise 2 - Pandas

# %% [markdown]
# Let's try subsetting and filtering on the [Kaggle 2021 Machine Learning and Data Science Survey](https://www.kaggle.com/c/kaggle-survey-2021/) dataset

# %%
import pandas as pd

# %%
## Read in the data
## Note that we won't create a composite column name this time
kaggle2021 = pd.read_csv('../data/kaggle_survey_2021_responses.csv')
# Out:
# /home/tpaskhalis/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (0,195,201,285,286,287,288,289,290,291,292) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
## Show top 5 rows
kaggle2021.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 910                        50-54
# 2                                 784                        50-54
# 3                                 924                        22-24
# 4                                 575                        45-49
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                  Indonesia
# 3                                   Pakistan
# 4                                     Mexico
#
# ...

# %%
## Show bottom 5 rows
kaggle2021.tail()
# Out:
#       Time from Start to Finish (seconds)     Q1   Q2  \
# 25969                                1756  30-34  Man
# 25970                                 253  22-24  Man
# 25971                                 494  50-54  Man
# 25972                                 277  45-49  Man
# 25973                                 255  18-21  Man
#
#                              Q3                 Q4                  Q5  \
# 25969                     Egypt  Bachelor’s degree        Data Analyst
# 25970                     China    Master’s degree             Student
# 25971                    Sweden    Doctoral degree  Research Scientist
# 25972  United States of America    Master’s degree      Data Scientist
# 25973                     India  Bachelor’s degree    Business Analyst
#
#                               Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 25969                  1-3 years    Python       NaN       SQL  ...
# 25970                  1-3 years    Python       NaN       NaN  ...
# ...

# %%
## Let's remove the first row that contains the question formulation
kaggle2021 = kaggle2021.drop(0)
kaggle2021
# Out:
#       Time from Start to Finish (seconds)     Q1   Q2  \
# 1                                     910  50-54  Man
# 2                                     784  50-54  Man
# 3                                     924  22-24  Man
# 4                                     575  45-49  Man
# 5                                     781  45-49  Man
# ...                                   ...    ...  ...
# 25969                                1756  30-34  Man
# 25970                                 253  22-24  Man
# 25971                                 494  50-54  Man
# 25972                                 277  45-49  Man
# 25973                                 255  18-21  Man
#
#                              Q3                 Q4                       Q5  \
# 1                         India  Bachelor’s degree                    Other
# 2                     Indonesia    Master’s degree  Program/Project Manager
# 3                      Pakistan    Master’s degree        Software Engineer
# ...

# %% [markdown]
# ### Task 1: Subset rows 100 to 110 from the dataset

# %%
## Add you code here

# %% [markdown]
# ### Task 2: Subset columns 1 to 5

# %%
## Add you code here

# %% [markdown]
# ### Task 3: Subset columns with all choices for Q7

# %%
## Add you code here

# %% [markdown]
# ### (Extra) Task 4: Filter dataset leaving only respondents who took more than 2 mins to respond. How many are dropped?
#
# Tip: As the correct parsing of column types was prevented by the first row with question formulation that we removed being string, you will need to convert the column type to numeric first. One way to achieve it is by using `pd.to_numeric()` method.

# %%
## Add you code here
