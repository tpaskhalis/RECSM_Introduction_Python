# %% [markdown]
# ## Exercise 3 - Exploratory Data Analysis & Data Visualization
#
# Let's dig in further into the [Kaggle 2020 Machine Learning and Data Science Survey](https://www.kaggle.com/c/kaggle-survey-2020/) dataset

# %%
# It's a good practice to load all you modules at the very beginning
import pandas as pd
from plotnine import *

# %%
# Read in the data
# We can also use a remote URL as an input path
kaggle2020 = pd.read_csv(
    'https://raw.githubusercontent.com/tpaskhalis/RECSM_Introduction_Python/main/data/kaggle_survey_2020_responses.csv',
    skiprows = [1]
)

# %%
# And the same for the row containing actual questions asked
kaggle2020_qs = pd.read_csv(
    'https://raw.githubusercontent.com/tpaskhalis/RECSM_Introduction_Python/main/data/kaggle_survey_2020_responses.csv',
    nrows = 1
)

# %%
kaggle2020.head()
# Out:
#    Time from Start to Finish (seconds)     Q1   Q2                        Q3  \
# 0                                 1838  35-39  Man                  Colombia
# 1                               289287  30-34  Man  United States of America
# 2                                  860  35-39  Man                 Argentina
# 3                                  507  30-34  Man  United States of America
# 4                                   78  30-34  Man                     Japan
#
#                   Q4                 Q5           Q6 Q7_Part_1 Q7_Part_2  \
# 0    Doctoral degree            Student   5-10 years    Python         R
# 1    Master’s degree      Data Engineer   5-10 years    Python         R
# 2  Bachelor’s degree  Software Engineer  10-20 years       NaN       NaN
# 3    Master’s degree     Data Scientist   5-10 years    Python       NaN
# 4    Master’s degree  Software Engineer    3-5 years    Python       NaN
#
# ...

# %%
kaggle2020_qs
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
#
#                                           Q3  \
# 0  In which country do you currently reside?
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
#
#                                            Q7_Part_1  \
# 0  What programming languages do you use on a reg...
#
#                                            Q7_Part_2  \
# 0  What programming languages do you use on a reg...
#
#                                            Q7_Part_3  ...  \
# ...

# %%
kaggle2020.describe()
# Out:
#        Time from Start to Finish (seconds)
# count                         2.003600e+04
# mean                          9.155865e+03
# std                           6.136760e+04
# min                           2.000000e+01
# 25%                           3.980000e+02
# 50%                           6.260000e+02
# 75%                           1.030250e+03
# max                           1.144493e+06

# %% [markdown]
# ### Task 1: Calculate the most frequent age group in the dataset. What percentage of all respondents falls into it?

# %%
## Add you code here

# %% [markdown]
# ### Task 2: Crosstabulate level of education and job title. What percentage of data scientists have a PhD? What percentage of PhDs work as research scientists?

# %%
## Add you code here

# %% [markdown]
# ### Task 3: Plot the frequencies of respondents' reported education level. Provide descriptive names to axes.
#
# Tips: You can use bar plot for it. Arguments in method `theme` allow adjusting different components of presentation. For example, `axis_text_x` controls text on X-axis.

# %%
## Add you code here
